# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.layers import Conv2D, UpSampling2D, Reshape,Input
import tensorflow.keras.backend as K
from tensorflow.keras.layers import concatenate

# %%
vgg19_cl = keras.applications.VGG19()
vgg19_cl.trainable = False
vgg19_cl.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 143,667,240
# Trainable params: 0
# Non-trainable params: 143,667,240
# _________________________________________________________________

# %%
inp_for_vgg = Input((224,224,3))
vgg19 = keras.applications.VGG19(include_top=False,input_shape=(224,224,3),weights="imagenet",)(inp_for_vgg)
vgg19.trainable = False
# print(vgg19.summary())
out_vgg19 = Conv2D(512, (3, 3), activation='relu', padding='same')(vgg19)

vgg19_ph = keras.Model(inp_for_vgg,out_vgg19)
vgg19_ph.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  conv2d (Conv2D)             (None, 7, 7, 512)         2359808
#
# =================================================================
# Total params: 22,384,192
# Trainable params: 22,384,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_out = keras.Sequential()
model_out.add(Input((7, 7, 533)))
model_out.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model_out.add(UpSampling2D((2, 2))) # 14 14 512
model_out.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model_out.add(UpSampling2D((2, 2)))  # 28 28 256
model_out.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model_out.add(UpSampling2D((2, 2))) # 56 56 128
model_out.add(Conv2D(64, (3, 3), activation='tanh', padding='same'))
model_out.add(UpSampling2D((2, 2))) # 112 112 64
model_out.add(Conv2D(32, (3, 3), activation='tanh', padding='same'))
model_out.add(UpSampling2D((2, 2))) # 224 224 32
model_out.add(Conv2D(32, (3, 3), activation='tanh', padding='same'))
model_out.add(Conv2D(1, (3, 3), activation='tanh', padding='same'))
model_out.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  up_sampling2d (UpSampling2D  (1, 14, 14, 533)         0
#  )
#
#  conv2d_1 (Conv2D)           (1, 14, 14, 128)          614144
#
#  up_sampling2d_1 (UpSampling  (1, 28, 28, 128)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (1, 28, 28, 64)           73792
#
#  up_sampling2d_2 (UpSampling  (1, 56, 56, 64)          0
#  2D)
#
#  conv2d_3 (Conv2D)           (1, 56, 56, 32)           18464
#
#  up_sampling2d_3 (UpSampling  (1, 112, 112, 32)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (1, 112, 112, 2)          578
#
#  up_sampling2d_4 (UpSampling  (1, 224, 224, 2)         0
#  2D)
#
# =================================================================
# Total params: 706,978
# Trainable params: 706,978
# Non-trainable params: 0
# _________________________________________________________________

# %%
# batch = 100
inp = Input((224, 224, 1),1)
inp_3d = Reshape((224,224,3))(concatenate([inp,inp,inp])) # 224 224 3

out_vgg19_cl = vgg19_cl(inp_3d) # 1000 output for class
out_vgg19_ph = vgg19_ph(inp_3d) # 7 7 512


cont_cl_zeros = concatenate([
    out_vgg19_cl,
    K.constant([[0 for _ in range(29)]for _ in range(out_vgg19_cl.shape[0])],dtype=tf.float32)
])
cont_cl_zeros_re = Reshape((7,7,21))(cont_cl_zeros)

concatenate_vgg_ph_cl = concatenate([
    out_vgg19_ph,
    cont_cl_zeros_re
]) # 7 7 533

output_model = model_out(concatenate_vgg_ph_cl)

model = keras.Model(inp,output_model)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(1, 224, 224, 1)]   0           []
#
#  concatenate (Concatenate)      (1, 224, 224, 3)     0           ['input_5[0][0]',
#                                                                   'input_5[0][0]',
#                                                                   'input_5[0][0]']
#
#  reshape (Reshape)              (1, 224, 224, 3)     0           ['concatenate[0][0]']
#
#  vgg19 (Functional)             (None, 1000)         143667240   ['reshape[0][0]']
#
#  concatenate_1 (Concatenate)    (1, 1029)            0           ['vgg19[0][0]']
#
#  model (Functional)             (None, 7, 7, 512)    22384192    ['reshape[0][0]']
#
#  reshape_1 (Reshape)            (1, 7, 7, 21)        0           ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (1, 7, 7, 533)       0           ['model[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  sequential (Sequential)        (1, 224, 224, 2)     706978      ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 166,758,410
# Trainable params: 23,091,170
# Non-trainable params: 143,667,240
# __________________________________________________________________________________________________

# %%
import data_preparation as dp
# x,ab,y = dp.create_data_imagenet()
# y.shape = (1,224,224,3)
# # y = y / 255
x,y = dp.avg_photo()

# %%
model.compile(optimizer="adam",
             loss='categorical_crossentropy',
             metrics=['accuracy'])
model.fit(x,x,epochs=50)
# Out:
# Epoch 1/50
# 2023-04-22 17:31:19.061201: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 2s 2s/step - loss: 0.6651 - accuracy: 0.7535
# Epoch 2/50
# 1/1 [==============================] - 1s 922ms/step - loss: 1.0433 - accuracy: 0.4860
# Epoch 3/50
# 1/1 [==============================] - 1s 775ms/step - loss: 1.0540 - accuracy: 0.1325
# Epoch 4/50
# 1/1 [==============================] - 1s 725ms/step - loss: 0.9901 - accuracy: 0.5615
# Epoch 5/50
# 1/1 [==============================] - 1s 808ms/step - loss: 0.9492 - accuracy: 0.9077
# Epoch 6/50
# 1/1 [==============================] - 1s 733ms/step - loss: 0.9486 - accuracy: 0.9137
# Epoch 7/50
# 1/1 [==============================] - 1s 787ms/step - loss: 0.9486 - accuracy: 0.9138
# Epoch 8/50
# 1/1 [==============================] - 1s 801ms/step - loss: 0.9485 - accuracy: 0.9137
# Epoch 9/50
# 1/1 [==============================] - 1s 777ms/step - loss: 0.9485 - accuracy: 0.9138
# Epoch 10/50
# 1/1 [==============================] - 1s 718ms/step - loss: 0.9468 - accuracy: 0.9212
# Epoch 11/50
# 1/1 [==============================] - 1s 676ms/step - loss: 0.9481 - accuracy: 0.9212
# Epoch 12/50
# 1/1 [==============================] - 1s 700ms/step - loss: 0.8087 - accuracy: 0.9211
# Epoch 13/50
# 1/1 [==============================] - 1s 678ms/step - loss: 0.7759 - accuracy: 0.9212
# Epoch 14/50
# 1/1 [==============================] - 1s 740ms/step - loss: 0.3542 - accuracy: 0.9212
# Epoch 15/50
# 1/1 [==============================] - 1s 750ms/step - loss: 0.0058 - accuracy: 0.9212
# Epoch 16/50
# 1/1 [==============================] - 1s 713ms/step - loss: 0.0033 - accuracy: 0.9212
# Epoch 17/50
# 1/1 [==============================] - 1s 697ms/step - loss: 0.0030 - accuracy: 0.9210
# Epoch 18/50
# 1/1 [==============================] - 1s 692ms/step - loss: 0.0454 - accuracy: 0.8974
# Epoch 19/50
# 1/1 [==============================] - 1s 688ms/step - loss: 0.0109 - accuracy: 0.2426
# Epoch 20/50
# 1/1 [==============================] - 1s 794ms/step - loss: 0.0037 - accuracy: 0.1594
# Epoch 21/50
# 1/1 [==============================] - 1s 744ms/step - loss: 0.0036 - accuracy: 0.1533
# Epoch 22/50
# 1/1 [==============================] - 1s 730ms/step - loss: 0.0035 - accuracy: 0.2052
# Epoch 23/50
# 1/1 [==============================] - 1s 774ms/step - loss: 0.0033 - accuracy: 0.1716
# Epoch 24/50
# 1/1 [==============================] - 1s 737ms/step - loss: 0.0033 - accuracy: 0.1497
# Epoch 25/50
# 1/1 [==============================] - 1s 729ms/step - loss: 0.0032 - accuracy: 0.1611
# Epoch 26/50
# 1/1 [==============================] - 1s 720ms/step - loss: 0.0031 - accuracy: 0.3160
# Epoch 27/50
# 1/1 [==============================] - 1s 697ms/step - loss: 0.0030 - accuracy: 0.9019
# Epoch 28/50
# 1/1 [==============================] - 1s 691ms/step - loss: 0.0029 - accuracy: 0.9054
# Epoch 29/50
# 1/1 [==============================] - 1s 692ms/step - loss: 0.1569 - accuracy: 0.8672
# Epoch 30/50
# 1/1 [==============================] - 1s 793ms/step - loss: 0.0028 - accuracy: 0.9118
# Epoch 31/50
# 1/1 [==============================] - 1s 813ms/step - loss: 0.0027 - accuracy: 0.8495
# Epoch 32/50
# 1/1 [==============================] - 1s 816ms/step - loss: 0.0026 - accuracy: 0.9171
# Epoch 33/50
# 1/1 [==============================] - 1s 890ms/step - loss: 0.0026 - accuracy: 0.9171
# Epoch 34/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.3841 - accuracy: 0.4161
# Epoch 35/50
# 1/1 [==============================] - 1s 826ms/step - loss: 0.0039 - accuracy: 0.7832
# Epoch 36/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0024 - accuracy: 0.8825
# Epoch 37/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0023 - accuracy: 0.9212
# Epoch 38/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0022 - accuracy: 0.9212
# Epoch 39/50
# 1/1 [==============================] - 1s 786ms/step - loss: 0.0022 - accuracy: 0.9212
# Epoch 40/50
# 1/1 [==============================] - 1s 865ms/step - loss: 0.0021 - accuracy: 0.9212
# Epoch 41/50
# 1/1 [==============================] - 1s 862ms/step - loss: 0.0021 - accuracy: 0.9212
# Epoch 42/50
# 1/1 [==============================] - 1s 866ms/step - loss: 0.0020 - accuracy: 0.9212
# Epoch 43/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.1865 - accuracy: 0.4473
# Epoch 44/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0019 - accuracy: 0.9212
# Epoch 45/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.0019 - accuracy: 0.9212
# Epoch 46/50
# 1/1 [==============================] - 2s 2s/step - loss: 0.0034 - accuracy: 0.8577
# Epoch 47/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0024 - accuracy: 0.8421
# Epoch 48/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0018 - accuracy: 0.9212
# Epoch 49/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0018 - accuracy: 0.9212
# Epoch 50/50
# 1/1 [==============================] - 1s 1s/step - loss: 0.0017 - accuracy: 0.9212

# %%
a = model.predict(x)
# k = dp.lab_ab_in_rgb(x,a)

plt.imshow(np.squeeze(a))
# Out:
# 1/1 [==============================] - 1s 881ms/step
# 0
